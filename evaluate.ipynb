# %%
import os
import json
import pandas as pd
from e_inference import run_inference_pipeline, CORRECTIONS_DIR, INPUT_DIR

def find_corresponding_input_file(base_name):
    """Finds the original input file (PDF, PNG, JPG) for a given base name."""
    for ext in ['.pdf', '.png', '.jpg', '.jpeg']:
        input_path = os.path.join(INPUT_DIR, base_name + ext)
        if os.path.exists(input_path):
            return input_path
    return None

def flatten_json_for_eval(data):
    """Converts the nested JSON into a flat set of strings for easy comparison."""
    flat_items = set()
    # Flatten patient info
    for key, value in data.get('patient_info', {}).items():
        # Normalize key and value for consistent comparison
        key_norm = str(key).strip().lower()
        value_norm = str(value).strip().lower()
        if value_norm: # Only add if there is a value
            flat_items.add(f"patient_{key_norm}={value_norm}")

    # Flatten lab results, using a primary key to identify each row
    lab_results = data.get('lab_results', [])
    # Find the most likely primary key (e.g., 'Investigation', 'Test Name')
    primary_key = None
    if lab_results:
        potential_keys = lab_results[0].keys()
        for key in potential_keys:
            if 'investigation' in key.lower() or 'test' in key.lower():
                primary_key = key
                break
        if not primary_key:
            primary_key = next(iter(potential_keys), None)

    if primary_key:
        for row in lab_results:
            row_id = str(row.get(primary_key, 'unknown_row')).strip().lower()
            for key, value in row.items():
                if key == primary_key: continue
                
                key_norm = str(key).strip().lower()
                value_norm = str(value).strip().lower()
                if value_norm:
                    flat_items.add(f"result_{row_id}_{key_norm}={value_norm}")
            
    return flat_items

def compare_extractions(ground_truth, prediction):
    """
    Compares extractions by flattening the data structures into sets.
    Returns counts of True Positives (TP), False Positives (FP), and False Negatives (FN).
    """
    gt_set = flatten_json_for_eval(ground_truth)
    pred_set = flatten_json_for_eval(prediction)

    tp = len(gt_set.intersection(pred_set))
    fp = len(pred_set - gt_set)
    fn = len(gt_set - pred_set)
    
    return tp, fp, fn

def run_evaluation():
    """Main function to run the evaluation across all corrected files."""
    total_tp, total_fp, total_fn = 0, 0, 0
    results = []

    corrected_files = [f for f in os.listdir(CORRECTIONS_DIR) if f.endswith('_corrected.json')]
    
    if not corrected_files:
        print(" No corrected files found. Cannot run evaluation.")
        return

    print(f"Found {len(corrected_files)} corrected files. Starting evaluation...")
    print("-" * 50)

    for filename in corrected_files:
        base_name = filename.replace('_corrected.json', '')
        
        with open(os.path.join(CORRECTIONS_DIR, filename), 'r', encoding='utf-8') as f:
            ground_truth_data = json.load(f)
        
        original_file_path = find_corresponding_input_file(base_name)
        if not original_file_path:
            print(f"⚠️  Skipping '{filename}': Could not find original input file.")
            continue
            
        print(f"Processing: {os.path.basename(original_file_path)}...")
        predicted_data = run_inference_pipeline(original_file_path)

        tp, fp, fn = compare_extractions(ground_truth_data, predicted_data)
        
        total_tp += tp
        total_fp += fp
        total_fn += fn
        
        results.append({"File": base_name, "Correct (TP)": tp, "Incorrect (FP)": fp, "Missed (FN)": fn})

    precision = total_tp / (total_tp + total_fp) if (total_tp + total_fp) > 0 else 0
    recall = total_tp / (total_tp + total_fn) if (total_tp + total_fn) > 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    print("\n" + "="*50 + "\nEVALUATION RESULTS\n" + "="*50)
    if results:
        df = pd.DataFrame(results)
        print(df.to_string(index=False))
    
    print("\n" + "-"*50 + "\nOverall Performance Metrics:\n" + f"  Precision: {precision:.2%}\n" + f"  Recall:    {recall:.2%}\n" + f"  F1-Score:  {f1_score:.2%}\n" + "-"*50)

if __name__ == "__main__":
    run_evaluation()
# Out:
# Found 9 corrected files. Starting evaluation...
# --------------------------------------------------
# Processing: 17756177_50641000301.pdf...
# {'patient_info': {'Name': 'Mr K P SHRAVAN Gender: Male LabID : 50641000301', 'Age’': '40 Years Mob. No. : 9035707662 Pt.ID : 6186848', 'B2B_ SC': 'Ref. By © VIKRAMKAMATH Pt. Loc', 'Reg Date and Time =': '29-Jun-2025 06:37 Report Date and Time : Ref Id1'}, 'lab_results': [{'Test Name': {'value': 'Adjusted Calcium', 'confidence': 95.0}, 'Result Value': {'value': '8.1', 'confidence': 96.0}, 'Unit': {'value': 'mg/dL', 'confidence': 81.0}, 'Reference Range': {'value': '8.8 10.4', 'confidence': 90.0}}, {'Test Name': {'value': 'Chloride', 'confidence': 96.0}, 'Result Value': {'value': '109', 'confidence': 96.0}, 'Unit': {'value': 'mEq/L', 'confidence': 82.0}, 'Reference Range': {'value': '98 107', 'confidence': 92.0}}, {'Test Name': {'value': 'LDL Cholesterol (Direct)', 'confidence': 95.0}, 'Result Value': {'value': '32', 'confidence': 96.0}, 'Unit': {'value': 'mg/dL', 'confidence': 81.0}, 'Reference Range': {'value': '<100 Optimal', 'confidence': 92.0}}, {'Test Name': {'value': 'Active B12', 'confidence': 93.0}, 'Result Value': {'value': '> 256.0', 'confidence': 95.0}, 'Unit': {'value': 'pmol/L', 'confidence': 96.0}, 'Reference Range': {'value': '25.1 165.0', 'confidence': 88.0}}, {'Test Name': {'value': 'Homocysteine', 'confidence': 96.0}, 'Result Value': {'value': '7.02', 'confidence': 95.0}, 'Unit': {'value': '6.6 14.8', 'confidence': 85.0}, 'Reference Range': {'value': '', 'confidence': 100.0}}, {'Test Name': {'value': 'RBC (Electrical Impedance)', 'confidence': 93.0}, 'Result Value': {'value': '5.31', 'confidence': 95.0}, 'Unit': {'value': '4.2 6.5', 'confidence': 92.0}, 'Reference Range': {'value': '', 'confidence': 100.0}}, {'Test Name': {'value': 'Total WBC Count', 'confidence': 96.0}, 'Result Value': {'value': '7000', 'confidence': 96.0}, 'Unit': {'value': '4000 11000', 'confidence': 80.0}, 'Reference Range': {'value': '', 'confidence': 100.0}}, {'Test Name': {'value': 'Platelet Count', 'confidence': 95.0}, 'Result Value': {'value': '335000', 'confidence': 96.0}, 'Unit': {'value': '150000', 'confidence': 85.0}, 'Reference Range': {'value': '', 'confidence': 100.0}}, {'Test Name': {'value': 'LDL CHOL/HDL CHOL', 'confidence': 90.0}, 'Result Value': {'value': '0.7', 'confidence': 96.0}, 'Unit': {'value': '<3.5', 'confidence': 92.0}, 'Reference Range': {'value': '', 'confidence': 100.0}}, {'Test Name': {'value': 'Chol/HDL', 'confidence': 90.0}, 'Result Value': {'value': '2.6', 'confidence': 96.0}, 'Unit': {'value': '<4.5', 'confidence': 88.0}, 'Reference Range': {'value': '', 'confidence': 100.0}}, {'Test Name': {'value': 'TSH', 'confidence': 95.0}, 'Result Value': {'value': '1.45', 'confidence': 96.0}, 'Unit': {'value': '0.35 4.94', 'confidence': 93.0}, 'Reference Range': {'value': '', 'confidence': 100.0}}, {'Test Name': {'value': 'Estimated Avg Glucose (3', 'confidence': 96.0}, 'Result Value': {'value': '111.15', 'confidence': 95.0}, 'Unit': {'value': 'Not available', 'confidence': 95.0}, 'Reference Range': {'value': '', 'confidence': 100.0}}, {'Test Name': {'value': 'Albumin / Globulin RATIO', 'confidence': 89.0}, 'Result Value': {'value': '1.85', 'confidence': 95.0}, 'Unit': {'value': '1.5-2.5', 'confidence': 91.0}, 'Reference Range': {'value': '', 'confidence': 100.0}}, {'Test Name': {'value': 'Sodium', 'confidence': 96.0}, 'Result Value': {'value': '140', 'confidence': 96.0}, 'Unit': {'value': '136 145', 'confidence': 89.0}, 'Reference Range': {'value': '', 'confidence': 100.0}}, {'Test Name': {'value': 'Potassium', 'confidence': 96.0}, 'Result Value': {'value': '4.36', 'confidence': 96.0}, 'Unit': {'value': '3.5 5.1', 'confidence': 59.0}, 'Reference Range': {'value': '', 'confidence': 100.0}}, {'Test Name': {'value': 'Chloride', 'confidence': 96.0}, 'Result Value': {'value': '109', 'confidence': 96.0}, 'Unit': {'value': '107', 'confidence': 95.0}, 'Reference Range': {'value': '', 'confidence': 100.0}}, {'Test Name': {'value': 'Active B12', 'confidence': 92.0}, 'Result Value': {'value': '> 256.0', 'confidence': 95.0}, 'U ...
# --- Attempting ML Model Extraction ---
#  ML model result was insufficient. Falling back to rule-based method.
#  Saved pending JSON to: project_data\pending_reports\17756177_50641000301_pending.json
# Using Rule-Based Fallback for extraction.
# Processing: 28396850_prabhakaran nair.pdf...
# {'patient_info': {'Lab. Id': 'P1238545 Hosp. UHID : Reg. Date : 17-Sep-2025 / 11:30 AM', 'Name': 'MR. PRABHAKARAN NAIR . Collection + 17-Sep-2025 / 11:31 AM', 'Collected At': 'Emami Frank Ross Limited Report : 17-Sep-2025 / 13:35 PM', 'Referral Dr se Report Status': 'Final Print :', 'Method': 'Indirect ISE', 'Remarks': '', 'Comments': '', 'Age': '72Y', 'Gender': 'Male Received ! 17-Sep-2025 / 12:13 PM'}, 'lab_results': [{'Investigation': {'value': 'SODIUM', 'confidence': 96.0}, 'Observed Value': {'value': '121', 'confidence': 96.0}, 'Unit': {'value': 'mmol/L', 'confidence': 96.0}, 'Biological Ref. Interval': {'value': '136-145', 'confidence': 96.0}, 'Specimen': {'value': 'Serum', 'confidence': 96.0}}, {'Investigation': {'value': 'POTASSIUM', 'confidence': 95.0}, 'Observed Value': {'value': '4.4', 'confidence': 96.0}, 'Unit': {'value': 'mmol/L', 'confidence': 96.0}, 'Biological Ref. Interval': {'value': '3.5-5.1', 'confidence': 75.0}, 'Specimen': {'value': 'Serum', 'confidence': 96.0}}, {'Investigation': {'value': 'CHLORIDE', 'confidence': 96.0}, 'Observed Value': {'value': '84', 'confidence': 95.0}, 'Unit': {'value': 'mmol/L', 'confidence': 96.0}, 'Biological Ref. Interval': {'value': '98-107', 'confidence': 96.0}, 'Specimen': {'value': 'Serum', 'confidence': 96.0}}], 'metadata': {'extraction_method': 'dynamic_rule_based_v6', 'num_tests_extracted': 3, 'detected_columns': ['Investigation', 'Observed Value', 'Unit', 'Biological Ref. Interval', 'Specimen']}}
# --- Attempting ML Model Extraction ---
#  ML model result was insufficient. Falling back to rule-based method.
#  Saved pending JSON to: project_data\pending_reports\28396850_prabhakaran nair_pending.json
# Using Rule-Based Fallback for extraction.
# Processing: 32187653_MRS. SATHYAVATHY.pdf...
# {'patient_info': {'Lab. Id': 'P0893801 Hosp. UHID Reg. Date —: 16-Sep-2025 / 12:26 PM', 'Name': 'MRS. SATHYAVATHY Collection + 16-Sep-2025 / 12:27 PM', 'Collected At': 'Emami Frank Ross Limited Report : 16-Sep-2025 / 15:03 PM', 'Referral Dr': 'Report Status : Final Print :', 'Method': 'Biuret Premature 3.6-6.0', 'TOTAL PROTEIN 7.1 g/dL Umbilical cord =': '4.8-8.8 Serum', 'New born': '4.6-7.0', 'Age': '7ZOY', 'Gender': 'Female Received : 16-Sep-2025 / 13:09 PM'}, 'lab_results': [{'Investigation': {'value': 'BILIRUBIN TOTAL', 'confidence': 96.0}, 'Observed Value': {'value': '0.44', 'confidence': 94.0}, 'Unit': {'value': 'mg/dl', 'confidence': 92.0}, 'Biological Ref. Interval': {'value': '<0.9', 'confidence': 88.0}, 'Specimen': {'value': 'Serum', 'confidence': 96.0}}, {'Investigation': {'value': 'BILIRUBIN DIRECT', 'confidence': 96.0}, 'Observed Value': {'value': '0.26', 'confidence': 95.0}, 'Unit': {'value': 'mg/dl', 'confidence': 92.0}, 'Biological Ref. Interval': {'value': '<0.30', 'confidence': 91.0}, 'Specimen': {'value': 'Serum', 'confidence': 96.0}}, {'Investigation': {'value': 'BILIRUBIN INDIRECT', 'confidence': 95.0}, 'Observed Value': {'value': '0.18', 'confidence': 96.0}, 'Unit': {'value': 'mg/dl', 'confidence': 92.0}, 'Biological Ref. Interval': {'value': '0.1-1.0', 'confidence': 88.0}, 'Specimen': {'value': 'Serum', 'confidence': 96.0}}, {'Investigation': {'value': 'TOTAL PROTEIN', 'confidence': 96.0}, 'Observed Value': {'value': '7.1', 'confidence': 94.0}, 'Unit': {'value': 'g/dL', 'confidence': 89.0}, 'Biological Ref. Interval': {'value': 'Umbilical cord =: 4.8-8.8', 'confidence': 69.0}, 'Specimen': {'value': 'Serum', 'confidence': 96.0}}, {'Investigation': {'value': 'ALBUMIN', 'confidence': 96.0}, 'Observed Value': {'value': '3.9', 'confidence': 96.0}, 'Unit': {'value': 'g/L', 'confidence': 96.0}, 'Biological Ref. Interval': {'value': 'Adults : 3.5-5.2', 'confidence': 66.0}, 'Specimen': {'value': 'Serum', 'confidence': 96.0}}, {'Investigation': {'value': 'GLOBULIN', 'confidence': 95.0}, 'Observed Value': {'value': '3.2', 'confidence': 95.0}, 'Unit': {'value': 'g/dL', 'confidence': 94.0}, 'Biological Ref. Interval': {'value': '2.3-3.5', 'confidence': 88.0}, 'Specimen': {'value': 'Serum', 'confidence': 96.0}}, {'Investigation': {'value': 'A/G RATIO', 'confidence': 96.0}, 'Observed Value': {'value': '1.22', 'confidence': 95.0}, 'Unit': {'value': '', 'confidence': 100.0}, 'Biological Ref. Interval': {'value': '1-2', 'confidence': 88.0}, 'Specimen': {'value': 'Serum', 'confidence': 96.0}}, {'Investigation': {'value': 'SGPT (ALT)', 'confidence': 94.0}, 'Observed Value': {'value': '22', 'confidence': 96.0}, 'Unit': {'value': 'U/L', 'confidence': 94.0}, 'Biological Ref. Interval': {'value': '10-35', 'confidence': 96.0}, 'Specimen': {'value': 'Serum', 'confidence': 96.0}}, {'Investigation': {'value': 'GGT', 'confidence': 95.0}, 'Observed Value': {'value': '15', 'confidence': 93.0}, 'Unit': {'value': 'U/L', 'confidence': 94.0}, 'Biological Ref. Interval': {'value': '<40', 'confidence': 92.0}, 'Specimen': {'value': 'Serum', 'confidence': 96.0}}, {'Investigation': {'value': 'ALKALINE PHOSPHATASE', 'confidence': 96.0}, 'Observed Value': {'value': '67', 'confidence': 96.0}, 'Unit': {'value': 'U/L', 'confidence': 94.0}, 'Biological Ref. Interval': {'value': '35-104', 'confidence': 96.0}, 'Specimen': {'value': 'Serum', 'confidence': 96.0}}], 'metadata': {'extraction_method': 'dynamic_rule_based_v6', 'num_tests_extracted': 10, 'detected_columns': ['Investigation', 'Observed Value', 'Unit', 'Biological Ref. Interval', 'Specimen']}}
# --- Attempting ML Model Extraction ---
#  ML model result was insufficient. Falling back to rule-based method.
#  Saved pending JSON to: project_data\pending_reports\32187653_MRS. SATHYAVATHY_pending.json
# Using Rule-Based Fallback for extraction.
# Processing: 53132939_MR. PRABHAKARAN.pdf...
# {'patient_info': {'Lab. Id': 'P1238545 Hosp. UHID : Reg. Date : 17-Sep-2025 / 11:30 AM', 'Name': 'MR. PRABHAKARAN NAIR . Collection + 17-Sep-2025 / 11:31 AM', 'Collected At': 'Emami Frank Ross Limited Report : 17-Sep-2025 / 13:35 PM', 'Referral Dr se Report Status': 'Final Print :', 'Method': 'Indirect ISE', 'Remarks': '', 'Comments': '', 'Age': '72Y', 'Gender': 'Male Received ! 17-Sep-2025 / 12:13 PM'}, 'lab_results': [{'Investigation': {'value': 'SODIUM', 'confidence': 96.0}, 'Observed Value': {'value': '121', 'confidence': 96.0}, 'Unit': {'value': 'mmol/L', 'confidence': 96.0}, 'Biological Ref. Interval': {'value': '136-145', 'confidence': 96.0}, 'Specimen': {'value': 'Serum', 'confidence': 96.0}}, {'Investigation': {'value': 'POTASSIUM', 'confidence': 95.0}, 'Observed Value': {'value': '4.4', 'confidence': 96.0}, 'Unit': {'value': 'mmol/L', 'confidence': 96.0}, 'Biological Ref. Interval': {'value': '3.5-5.1', 'confidence': 75.0}, 'Specimen': {'value': 'Serum', 'confidence': 96.0}}, {'Investigation': {'value': 'CHLORIDE', 'confidence': 96.0}, 'Observed Value': {'value': '84', 'confidence': 95.0}, 'Unit': {'value': 'mmol/L', 'confidence': 96.0}, 'Biological Ref. Interval': {'value': '98-107', 'confidence': 96.0}, 'Specimen': {'value': 'Serum', 'confidence': 96.0}}], 'metadata': {'extraction_method': 'dynamic_rule_based_v6', 'num_tests_extracted': 3, 'detected_columns': ['Investigation', 'Observed Value', 'Unit', 'Biological Ref. Interval', 'Specimen']}}
# --- Attempting ML Model Extraction ---
#  ML model result was insufficient. Falling back to rule-based method.
#  Saved pending JSON to: project_data\pending_reports\53132939_MR. PRABHAKARAN_pending.json
# Using Rule-Based Fallback for extraction.
# Processing: 72829849_MultiLabIdReport.pdf...
# {'patient_info': {'Name _': 'Ms. RATHNA GABRIAL Gender . Female LabID ~: 50635928369', 'Age’ =': '79 Years Mob. No. : Pt. ID', 'B2B': 'EMAMI FRANK ROSS LIMITED Ref.By . Pt. Loc', 'Reg Date and Time - 30-Jun-2025 16': '13 Report Date and Time <: 30-Jun-2025 18:18 Ref Id1', 'Sample Received at': 'KA-Shivajinagar Ref Id2', 'Serum Coll. Time': '30-Jun-2025 16:14', 'Note': ''}, 'lab_results': [], 'metadata': {'extraction_method': 'dynamic_rule_based_v6', 'num_tests_extracted': 0, 'detected_columns': ['TEST', 'RESULTS', 'UNIT', 'BIOLOGICAL REF RANGE REMARKS']}}
# --- Attempting ML Model Extraction ---
#  ML model result was insufficient. Falling back to rule-based method.
#  Saved pending JSON to: project_data\pending_reports\72829849_MultiLabIdReport_pending.json
# Using Rule-Based Fallback for extraction.
# Processing: 82226685_Report_50636000175_RATHNA GABRIAL.pdf...
# {'patient_info': {'Name_': 'Mrs RATHNA GABRIAL Gender .: Female LabID_ .: 50636000175', 'Age’': '79 Years Mob. No. : Pt. ID', 'B2B =': 'EMAMI FRANK ROSS LIMITED Ref.By . Pt. Loc', 'Reg Date and Time =. 03-Jun-2025 08': '37 Report Date and Time: 03-Jun-2025 11:41 Ref Id1', 'Sample Received at': 'KA-Kasturinagar Ref Id2', 'HEXOKINASE/G-6-PDH 100 125 mg/dl': '', '>/= 126 mg/dl': 'Diabetes.', 'Plasma Fluoride F Coll. Time': '03-Jun-2025 08:45'}, 'lab_results': [], 'metadata': {'extraction_method': 'dynamic_rule_based_v6', 'num_tests_extracted': 0, 'detected_columns': ['TEST', 'RESULTS', 'UNIT', 'BIOLOGICAL REF RANGE REMARKS']}}
# --- Attempting ML Model Extraction ---
#  ML model result was insufficient. Falling back to rule-based method.
#  Saved pending JSON to: project_data\pending_reports\82226685_Report_50636000175_RATHNA GABRIAL_pending.json
# Using Rule-Based Fallback for extraction.
# Processing: 85496534_77e377bf-8723-488e-b33d-cbde2becae3c NAGASHANKAR RAO.pdf...
# {'patient_info': {'Regd. Office': 'Dr Lal Path abs Ltd, Block-E, Sector-18, Rohini, New Dethi-1 10085', 'Web': 'www iaipathiabs com, CIN: L74899DL 1 99S5PLC065 388', 'Name': 'Mr. K NAGASHANKAR RAO', 'Lab No.': '466878783 Age : 63 Years', 'Ref By': 'Self Gender : Male', 'Collected 1/8/2024 8': '45:00AM Reported 1/8/2024 8:14:03PM', 'Alc Status': 'P Report Status Final', 'Collected at': 'RELEX HEALTHCARE INDIA Pvt. Ltd. Processed at LPL-BENGALURU REFERENCE LAB'}, 'lab_results': [], 'metadata': {'extraction_method': 'dynamic_rule_based_v6', 'num_tests_extracted': 0, 'detected_columns': ['Test Name', 'Results', 'Units', 'Bio. Ref. Interval']}}
# --- Attempting ML Model Extraction ---
#  ML model result was insufficient. Falling back to rule-based method.
#  Saved pending JSON to: project_data\pending_reports\85496534_77e377bf-8723-488e-b33d-cbde2becae3c NAGASHANKAR RAO_pending.json
# Using Rule-Based Fallback for extraction.
# Processing: 91681339_f3b8288c-4bcf-4c1c-b242-e05f152b8e62 SWARNA LATA.pdf...
# {'patient_info': {'Regd. Office': 'Dr Lal Path abs Ltd, Block-E, Sector-18, Rohini, New Dethi-1 10085', 'Web': 'www iaipathiabs com, CIN: L74899DL 1 99SPLC065 388', 'Name': 'Mrs. SWARNA LATA', 'Lab No.': '466917439 Age : 41 Years', 'Ref By': 'Self Gender : Female', 'Collected 8/8/2024 7': '50:00AM Reported 9/8/2024 10:06:36AM', 'Alc Status': 'P Report Status : Final', 'Collected at}': 'RELEX HEALTHCARE INDIA Pvt. Ltd. Processed at : LPL-BENGALURU REFERENCE LAB'}, 'lab_results': [], 'metadata': {'extraction_method': 'dynamic_rule_based_v6', 'num_tests_extracted': 0, 'detected_columns': ['Test Name', 'Results', 'Units', 'Bio. Ref. Interval']}}
# --- Attempting ML Model Extraction ---
#  ML model result was insufficient. Falling back to rule-based method.
#  Saved pending JSON to: project_data\pending_reports\91681339_f3b8288c-4bcf-4c1c-b242-e05f152b8e62 SWARNA LATA_pending.json
# Using Rule-Based Fallback for extraction.
# Processing: 97308261_Mr. MANISH BAJPIE.pdf...
# {'patient_info': {'Regd. Office': 'Dr Lal Path abs Ltd, Block-E, Sector-18, Rohini, New Dethi-1 10085', 'Web': 'www iaipathiabs com, CIN: L74899DL 1 99SPLC065 388', 'Name': 'Mr. MANISH BAJPIE', 'Lab No.': '466917440 Age : 48 Years', 'Ref By': 'Self Gender : Male', 'Collected 8/8/2024 7': '30:00AM Reported 9/8/2024 3:13:56PM', 'Alc Status': 'P Report Status : Final', 'Collected at': 'RELEX HEALTHCARE INDIA Pvt. Ltd. Processed at : LPL-BENGALURU REFERENCE LAB'}, 'lab_results': [], 'metadata': {'extraction_method': 'dynamic_rule_based_v6', 'num_tests_extracted': 0, 'detected_columns': ['Test Name', 'Results', 'Units', 'Bio. Ref. Interval']}}
# --- Attempting ML Model Extraction ---
#  ML model result was insufficient. Falling back to rule-based method.
#  Saved pending JSON to: project_data\pending_reports\97308261_Mr. MANISH BAJPIE_pending.json
# Using Rule-Based Fallback for extraction.
#
# ==================================================
# EVALUATION RESULTS
# ==================================================
#                                                          File  Correct (TP)  Incorrect (FP)  Missed (FN)
#                                          17756177_50641000301             4              16           76
#                                     28396850_prabhakaran nair             7               4            3
#                                     32187653_MRS. SATHYAVATHY             9              13            9
#                                      53132939_MR. PRABHAKARAN             7               4            3
#                                     72829849_MultiLabIdReport             6               0            1
#                    82226685_Report_50636000175_RATHNA GABRIAL             7               0            5
# 85496534_77e377bf-8723-488e-b33d-cbde2becae3c NAGASHANKAR RAO             8               0           21
#     91681339_f3b8288c-4bcf-4c1c-b242-e05f152b8e62 SWARNA LATA             8               0           20
#                                    97308261_Mr. MANISH BAJPIE             8               0           20
#
# --------------------------------------------------
# Overall Performance Metrics:
#   Precision: 63.37%
#   Recall:    28.83%
#   F1-Score:  39.63%
# --------------------------------------------------
